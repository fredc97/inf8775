# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

df = pd.read_csv("results.csv").groupby(['algo','serie','taille']).mean().reset_index()

g = sns.FacetGrid(df, col='serie', hue='algo', size=10, aspect=3)
g = g.map(plt.plot, 'taille', 'temps')
g.set(xscale='log')
g.set(yscale='log')
g.add_legend()
plt.savefig('test_puissance')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-93497f51f865> in <module>
#       4 import sys
#       5
# ----> 6 df = pd.read_csv("result.csv").groupby(['algo','serie','taille']).mean().reset_index()
#       7
#       8 g = sns.FacetGrid(df, col='serie', hue='algo', size=10, aspect=1)
#
# c:\users\frede\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\users\frede\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\frede\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\users\frede\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# c:\users\frede\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'result.csv' does not exist: b'result.csv'

# %%
df = pd.read_csv("results.csv").groupby(['algo','serie','taille']).mean().reset_index()

g = sns.FacetGrid(df, col='serie', hue='algo', size=7, aspect=1)
g = g.map(plt.plot, 'taille', 'temps')

plt.plot(x, y/math.log(x))
g.set(xscale='log')
g.set(yscale='log')
g.add_legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-38fe61509d08> in <module>
#       4 g = g.map(plt.plot, 'taille', 'temps')
#       5
# ----> 6 plt.plot(x, y/math.log(x))
#       7 g.set(xscale='log')
#       8 g.set(yscale='log')
#
# NameError: name 'x' is not defined
